# %% [markdown]
# # Bonus - Volatility Plots

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../output_hans/HourlyVolatilityByYear.csv')
df.head()
# Out:
#    Year SettlementPoint  HourlyVolatility
# 0  2016       HB_BUSAVG          0.403882
# 1  2016      HB_HOUSTON          0.397947
# 2  2016       HB_HUBAVG          0.420049
# 3  2016        HB_NORTH          0.389115
# 4  2016        HB_SOUTH          0.406438

# %%
df.shape
# Out:
# (600, 3)

# %%
uniq = df['SettlementPoint'].unique()
hubs = [i for i in uniq]
hubs
# Out:
# ['HB_BUSAVG',
#  'HB_HOUSTON',
#  'HB_HUBAVG',
#  'HB_NORTH',
#  'HB_SOUTH',
#  'HB_WEST',
#  'HB_PAN']

# %%
    ax = (
        df
        .pivot_table(
            values='HourlyVolatility',
            index='Year',
            columns='SettlementPoint'
            )
        .plot(
        
            y = hubs, 
            ylabel = 'HourlyVolatility',
            figsize = (16, 9)    
            )
    )
